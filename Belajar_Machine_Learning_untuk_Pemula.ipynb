# %% [markdown]
# <a href="https://colab.research.google.com/github/Vicysaragih/Machine_Learning_Developer/blob/main/Belajar_Machine_Learning_untuk_Pemula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Latihan Konversi Pandas Dataframe**

# %%
import os
os.listdir('sample_data')
# Out:
# ['anscombe.json',
#  'README.md',
#  'california_housing_train.csv',
#  'california_housing_test.csv',
#  'mnist_train_small.csv',
#  'mnist_test.csv']

# %%
import pandas as pd
df = pd.read_csv('sample_data/california_housing_train.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# **Data Preparation with Normalization**

# %%
from sklearn.preprocessing import MinMaxScaler
data = [[12000000, 33], [35000000, 45], [4000000, 23], [6500000, 26], [9000000, 29]]

# %%
# Fungsi fit() dari objek MinMaxScaler adalah fungsi
# untuk menghitung nilai minimum dan maksimum pada tiap kolom

scaler = MinMaxScaler()
scaler.fit(data)
# Out:
# MinMaxScaler()

# %%
# Panggil fungsi transform() yang akan mengaplikasikan scaler pada data

print(scaler.transform(data))
# Out:
# [[0.25806452 0.45454545]
#  [1.         1.        ]
#  [0.         0.        ]
#  [0.08064516 0.13636364]
#  [0.16129032 0.27272727]]

# %% [markdown]
# **Data Preparation with Standarization**

# %%
from sklearn import preprocessing
data = [[12000000, 33], [35000000, 45], [4000000, 23], [6500000, 26], [9000000, 29]]

# %%
#  Membuat object scaler dan panggil fungsi fit dari scaler pada data

scaler = preprocessing.StandardScaler().fit(data)  # fungsi untuk menghitung rata-rata dan
                                                   # deviasi standar dari setiap kolom atribut

# %%
# Panggil fungsi transform() yang akan mengaplikasikan scaler pada data

data = scaler.transform(data)
data
# Out:
# array([[-0.11638732,  0.23521877],
#        [ 1.94277296,  1.80334389],
#        [-0.83261698, -1.07155217],
#        [-0.60879521, -0.67952089],
#        [-0.38497344, -0.28748961]])

# %% [markdown]
# **Training Set dan Test Set**

# %%
from sklearn.model_selection import train_test_split


x_data = range(10)
y_data = range(10)

print("Random state ditentukan")
for i in range(3):
  x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.3, random_state = 42)
  print(y_test)

print("Random state tidak ditentukan")
for i in range(3):
  x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.3, random_state = None)
  print(y_test)
# Out:
# Random state ditentukan
# [8, 1, 5]
# [8, 1, 5]
# [8, 1, 5]
# Random state tidak ditentukan
# [4, 2, 9]
# [8, 9, 2]
# [1, 4, 7]

# %%
from sklearn.model_selection import train_test_split


x_data = range(10)
y_data = range(10)

print("Random state ditentukan")
for i in range(3):
  x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.3, random_state = 42)
  print(x_test)

print("Random state tidak ditentukan")
for i in range(3):
  x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.3, random_state = None)
  print(x_test)
# Out:
# Random state ditentukan
# [8, 1, 5]
# [8, 1, 5]
# [8, 1, 5]
# Random state tidak ditentukan
# [2, 9, 8]
# [3, 4, 8]
# [9, 6, 4]

# %%
from sklearn.model_selection import train_test_split


x_data = range(10)
y_data = range(10)

print("Random state ditentukan")
for i in range(4):
  x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.3, random_state = 42)
  print(x_test)

print("Random state tidak ditentukan")
for i in range(3):
  x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.3, random_state = None)
  print(x_test)
# Out:
# Random state ditentukan
# [8, 1, 5]
# [8, 1, 5]
# [8, 1, 5]
# [8, 1, 5]
# Random state tidak ditentukan
# [4, 6, 9]
# [2, 0, 4]
# [9, 0, 8]

# %%
from sklearn.model_selection import train_test_split


x_data = range(5)
y_data = range(5)

print("Random state ditentukan")
for i in range(4):
  x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.3, random_state = 42)
  print(x_test)

print("Random state tidak ditentukan")
for i in range(3):
  x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.3, random_state = None)
  print(x_test)
# Out:
# Random state ditentukan
# [1, 4]
# [1, 4]
# [1, 4]
# [1, 4]
# Random state tidak ditentukan
# [4, 2]
# [1, 3]
# [1, 4]

# %% [markdown]
# **Latihan SKLearn Train Test Split**

# %%
import sklearn
from sklearn import datasets

#Load iris dataset
iris = datasets.load_iris()

#Pisahkan atribut dan label dalam iris dataset
x = iris.data
y = iris.target

from sklearn.model_selection import train_test_split

# Membagi datasets menjadi train dan test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size =0.2, random_state = 1)

# Menghitung panjang/jumlah data x_test
len(x_test)
# Out:
# 30

# %% [markdown]
# # **Latihan SKLearn Cross Validation Split**
#
# 1.   Item daftar
# 2.   Item daftar

# %%
import sklearn
from sklearn import datasets

# Load iris dataset
iris = datasets.load_iris()

# mendefinisikan atribut dan label pada dataset
x=iris.data
y=iris.target

from sklearn import tree

# membuat model dengan decision tree classifier
clf = tree.DecisionTreeClassifier()

from sklearn.model_selection import cross_val_score

# mengevaluasi performa model dengan cross_val_score
scores = cross_val_score(clf, x, y, cv=5)

scores
# Out:
# array([0.96666667, 0.96666667, 0.9       , 0.93333333, 1.        ])

# %% [markdown]
# # **CLASSIFICATION**
#
# 1. Ubah dataset ke dalam dataframe.
#
# 2. Hapus kolom 'Id' pada dataframe serta pisahkan antara atribut dan label.
#
# 3. Bagi dataset menjadi data latih dan data uji.
#
# 4. Buat dan latih model Decision Tree.
#
# 5. Lakukan pengujian model dengan menggunakan data uji.
#
# 6. Lakukan prediksi dengan model yang telah dilatih.
#
# 7. Visualisasi model Decision Tree yang telah dilatih.

# %%
import pandas as pd

# Membaca file Iris_csv
Iris = pd.read_csv('Iris.csv')

# Melihat informasi dataset
Iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# Melihat informasi dataset dari 5 baris pertama
Iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Menghilangkan kolom yang tidak penting
Iris.drop('Id', axis = 1, inplace = True)

# %%
# Melihat informasi dataset dari 5 baris pertama
Iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Memisahkan atribut dan label
x = Iris[["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"]]
y = Iris["Species"]


# Membagi dataset menjadi train & test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size =0.1, random_state = 123 )

# %%
from sklearn.tree import DecisionTreeClassifier

# Membuat model Decision Tree
tree_model = DecisionTreeClassifier()

# Melatih model dengan menggunakan data latih menggunakan fungsi fit()
tree_model = tree_model.fit(x_train, y_train)

# %%
# Evaluasi Model
from sklearn.metrics import accuracy_score

y_pred = tree_model.predict(x_test)


acc_score = round(accuracy_score(y_pred, y_test), 3)

print("Accuracy: ", acc_score)
# Out:
# Accuracy:  0.933

# %%
# Evaluasi Model
from sklearn.metrics import accuracy_score

y_pred = tree_model.predict(x_test)


acc_score = round(accuracy_score(y_pred, y_test), 2)

print("Accuracy: ", acc_score)
# Out:
# Accuracy:  0.93

# %%
# prediksi model dengan tree_model.predict([[SepalLength, SepalWidth, PetalLength, PetalWidth]])
print(tree_model.predict([[6.2, 3.4, 5.4, 2.3]])[0])
# Out:
# Iris-virginica
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import export_graphviz
export_graphviz(
    tree_model,
    out_file = "iris_tree.dot",
    feature_names = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'],
    class_names = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica' ],
    rounded= True,
    filled =True)

# %% [markdown]
# # **REGRESSION**

# %% [markdown]
# # **Latihan SKLearn Linear Regression**

# %%
import numpy as np

# Membuat data jumlah kamar
bedrooms = np.array([1, 1, 2, 2, 3, 4, 4, 5, 5, 5])

# Data harga rumah, asumsi harga dollar
house_price = np.array([15000, 18000, 27000, 34000, 50000, 68000, 65000, 81000, 85000, 90000])

# %%
print(bedrooms)
# Out:
# [1 1 2 2 3 4 4 5 5 5]

# %%
# Menampilkan scatter plot
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(bedrooms, house_price)

# %%
from sklearn.linear_model import LinearRegression

# Latih model menggunakan LinearRegresion.fit()
bedrooms = bedrooms.reshape(-1, 1)

linreg = LinearRegression()
linreg.fit(bedrooms, house_price)
# Out:
# LinearRegression()

# %%
# Menampilkan hubungan antara jumlha kamar dengan harga rumah

plt.scatter(bedrooms, house_price)
plt.plot(bedrooms, (linreg.predict(bedrooms)))

# %%
from sklearn.linear_model import LinearRegression

# Latih model menggunakan LinearRegresion.fit()
bedrooms = bedrooms.reshape(-5, 1)

linreg = LinearRegression()
linreg.fit(bedrooms, house_price)
# Out:
# LinearRegression()

# %%
# Menampilkan hubungan antara jumlha kamar dengan harga rumah

plt.scatter(bedrooms, house_price)
plt.plot(bedrooms, (linreg.predict(bedrooms)))

# %% [markdown]
# ## **Latihan SKLearn Logistic Regression**
#
# **Tujuan**
#
# Pada latihan ini kita akan menggunakan logistic regression untuk memprediksi apakah seseorang akan membeli setelah melihat iklan sebuah produk.
#
# **Tahapan Latihan**
#
# Tahapan yang dilalui dalam latihan kali ini adalah sebagai berikut:
#
# 1. Ubah dataset menjadi Dataframe.
# 2. Hapus kolom 'User ID'.
# 3. Pisahkan atribut dan label.
# 4. Latih model Logistic Regression.
# 5. Evaluasi akurasi model.

# %%
import pandas as pd

df = pd.read_csv('Social_Network_Ads.csv')

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
# Drop kolom yang tidak perlu

data = df.drop(columns = ["User ID"])

# Jalankan proses One-Hot Encoding menggunakan pd.get_dummies()
data = pd.get_dummies(data, dtype = "int")
data
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Female  Gender_Male
# 0     19            19000          0              0            1
# 1     35            20000          0              0            1
# 2     26            43000          0              1            0
# 3     27            57000          0              1            0
# 4     19            76000          0              0            1
# ..   ...              ...        ...            ...          ...
# 395   46            41000          1              1            0
# 396   51            23000          1              0            1
# 397   50            20000          1              1            0
# 398   36            33000          0              0            1
# 399   49            36000          1              1            0
#
# [400 rows x 5 columns]

# %%
data.head()
# Out:
#    Age  EstimatedSalary  Purchased  Gender_Female  Gender_Male
# 0   19            19000          0              0            1
# 1   35            20000          0              0            1
# 2   26            43000          0              1            0
# 3   27            57000          0              1            0
# 4   19            76000          0              0            1

# %%
# pisahkan atribut dan label
predictions = ['Age' , 'EstimatedSalary' , 'Gender_Female' , 'Gender_Male']
X = data[predictions]
y = data['Purchased']

# %%
# Lakukan normalisasi terhadap data yang kita miliki
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
scaled_data = scaler.transform(X)
scaled_data = pd.DataFrame(scaled_data, columns = X.columns)
scaled_data.head()
# Out:
#         Age  EstimatedSalary  Gender_Female  Gender_Male
# 0 -1.781797        -1.490046      -1.020204     1.020204
# 1 -0.253587        -1.460681      -1.020204     1.020204
# 2 -1.113206        -0.785290       0.980196    -0.980196
# 3 -1.017692        -0.374182       0.980196    -0.980196
# 4 -1.781797         0.183751      -1.020204     1.020204

# %%
from sklearn.model_selection import train_test_split

# Membagi data menjadi train dan test
x_train, x_test, y_train, y_test = train_test_split(scaled_data, y, test_size = 0.2, random_state = 1)

# %%
from sklearn import linear_model

# Latih model dengan fungsi fit()
model = linear_model.LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# Uji akurasi model
model.score(x_test, y_test)
# Out:
# 0.825

# %% [markdown]
# # **# Latihan SKLearn K-means**
#
# Tahapan Latihan
#
# Tahapan pada latihan kali ini adalah sebagai berikut:
#
# 1. Konversi data menjadi Dataframe.
# 2. Lakukan preprocessing data.
# 3. Hilangkan kolom 'CustomerID' dan 'gender'.
# 4. Latih model K-Means.
# 5. Buat plot untuk Elbow dan Cluster.

# %%
import pandas as pd

# Ubah file csv menjadi DataFrame
df = pd.read_csv("Mall_Customers.csv")

df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# Mengubah nama kolom
df = df.rename(columns ={'Gender' : 'gender', 'Age' : 'age',
                         'Annual Income (k$)' : 'annual_income',
                         'Spending Score (1-100)' : 'spending_score'})

# Mengubah data katagorik menjadi data numerik
df['gender'].replace(['Female', 'Male'], [0, 1], inplace = True)

# Menampilkan data yang sudah di prepocess
df.head()
# Out:
#    CustomerID  gender  age  annual_income  spending_score
# 0           1       1   19             15              39
# 1           2       1   21             15              81
# 2           3       0   20             16               6
# 3           4       0   23             16              77
# 4           5       0   31             17              40

# %%
from sklearn.cluster import KMeans

# Menghapus kolom CustomerID dan gender
X = df.drop(['CustomerID', 'gender'], axis = 1)

X.head()
# Out:
#    age  annual_income  spending_score
# 0   19             15              39
# 1   21             15              81
# 2   20             16               6
# 3   23             16              77
# 4   31             17              40

# %%
# Membuat list yang berisi inertia
clusters =  []
for i in range(1, 11):
  km = KMeans(n_clusters = i).fit(X)
  clusters.append(km.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Membuat plot inertia
fig, ax = plt.subplots(figsize=(8, 4))
sns.lineplot(x=list(range(1, 11)), y=clusters, ax=ax)
ax.set_title('Cari Elbow')
ax.set_xlabel('Clusters')
ax.set_ylabel('Inertia')
# Out:
# Text(0, 0.5, 'Inertia')

# %%
# Membuat objek KMeans
km5 = KMeans(n_clusters=5).fit(X)

# Menambahkan kolom label pada dataset
X['Labels'] = km5.labels_

# membuat plot KMeans dengan 5 klaster
plt.figure(figsize=(8,4))
sns.scatterplot(x=X['annual_income'], y=X['spending_score'], hue=X['Labels'],
                palette=sns.color_palette('hls', 5))
plt.title('KMeans dengan 5 Cluster')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# #**Latihan SKLearn PCA**

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

iris = datasets.load_iris()
attribut = iris.data
label = iris.target

# Membagi dataset menjadi Train dan Test
x_train, x_test, y_train, y_test = train_test_split(attribut, label, test_size = 0.2, random_state = 1)

# %%
from sklearn import tree

decision_tree = tree.DecisionTreeClassifier()

# melatih Model
model_pertama = decision_tree.fit(x_train, y_train)

# Test akurasi
print("Akurasi tanpa PCA: ")
model_pertama.score(x_test, y_test)
# Out:
# Akurasi tanpa PCA:
# 0.9666666666666667

# %%
# Menggunakan PCA

from sklearn.decomposition import PCA

# Membuat objek PCA dengan 4 principal komponen
pca = PCA(n_components = 4)

# Mengaplikasi PCA pada dataset \
pca_attributes = pca.fit_transform(x_train)

# Melihat Variance dari setiap attribut
pca.explained_variance_ratio_
# Out:
# array([0.92848323, 0.04764372, 0.01931005, 0.004563  ])

# %%
# PCA dengan 2 Principal Componen
pca = PCA(n_components = 2)
x_train_pca = pca.fit_transform(x_train)
x_test_pca = pca.fit_transform(x_test)

# %%
# Menguji akurasi classifier
model2 = decision_tree.fit(x_train_pca, y_train)
model2.score(x_test_pca, y_test)
# Out:
# 0.9333333333333333

# %%
# PCA dengan 2 Principal Componen
pca = PCA(n_components = 3)
x_train_pca = pca.fit_transform(x_train)
x_test_pca = pca.fit_transform(x_test)

# Menguji akurasi classifier
model2 = decision_tree.fit(x_train_pca, y_train)
model2.score(x_test_pca, y_test)
# Out:
# 0.9

# %%
# PCA dengan 2 Principal Componen
pca = PCA(n_components = 1)
x_train_pca = pca.fit_transform(x_train)
x_test_pca = pca.fit_transform(x_test)

# Menguji akurasi classifier
model2 = decision_tree.fit(x_train_pca, y_train)
model2.score(x_test_pca, y_test)
# Out:
# 0.8

# %% [markdown]
# # **Latihan SKLearn SVM untuk Klasifikasi**

# %%
import pandas as pd


df = pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# Memisahkan atribut pada dataset dan menyimpannya pada variabel
X = df[df.columns[:8]]

# memisahkan label pada dataset dan menyimpannya pada sebuah variabel
y = df['Outcome']

# %%
from sklearn.preprocessing import StandardScaler

# Standarisasi nilai nilai pada dataset
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# %%
from sklearn.model_selection import train_test_split

# Memisahkan data untuk training dan test
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
from sklearn.svm import SVC

# Membuat fungsi svc dan memanggil fungsi fit untuk melatih model
clf = SVC()
clf.fit(x_train, y_train)
# Out:
# SVC()

# %%
# Menampilkan skor akurasi model
clf.score(x_test, y_test)
# Out:
# 0.7559055118110236

# %% [markdown]
# # **Latihan SKLearn SVR**

# %%
import pandas as pd

data = pd.read_csv('Salary_Data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
import numpy as np

# Memisahkan atribut dan label
X = data["YearsExperience"]
y = data["Salary"]

# Mengubah bentuk atribut
X = np.array(X)
X = X[:,np.newaxis]

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
from sklearn.svm import SVR

# Membangun model dengan parameter C, gamma dan kernel
model = SVR(C = 1000, gamma= 0.05, kernel='rbf')

# Melatih model dengan fungsi fit()
model.fit(X, y)
# Out:
# SVR(C=1000, gamma=0.05)

# %%
import matplotlib.pyplot as plt


# Memvisualisai model
plt.scatter(X, y)
plt.plot(X, model.predict(X))

# %% [markdown]
# # **Latihan SKLearn dengan Teknik Grid Search**
#
# **Tahapan Latihan**
#
#
# Tahapan latihan kali ini sebagai berikut:
#
# 1. Ubah dataset data menjadi Dataframe.
# 2. Definisikan parameter yang akan diuji.
# 3. Jalankan fungsi grid search.
# 4. Latih model dengan parameter terbaik hasil grid search.
# 5. Buat plot dari model.

# %%
import pandas as pd


# Membaca dataset dan mengubah menjadi dataframe
data = pd.read_csv("Salary_Data (1).csv")

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
import numpy as np

# Memisahkan atribut dan label
X = data["YearsExperience"]
y = data["Salary"]

# Mengubah bentuk atribut
X = np.array(X)
X = X.reshape(-1, 1)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

# Membangun model dengan paramater C, gamma, dan kernel
model = SVR()

# Membuat Python Dictionary dengan nama parameters yang akan diuji
parameters = {
    'kernel': ['rbf'],
    'C':     [1000, 10000, 100000],
    'gamma': [0.5, 0.05,0.005]
}

# Parameter Pertama = model yang akan diuji
# Parameter Kedua = dictionary yang berisi kumpulan parameter2
grid_search = GridSearchCV(model, parameters)


# Melatih Model dengan fungsi fit()
grid_search.fit(X, y)
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [1000, 10000, 100000],
#                          'gamma': [0.5, 0.05, 0.005], 'kernel': ['rbf']})

# %%
# Menampilkan parameter terbaik dari grid_search
print(grid_search.best_params_)
# Out:
# {'C': 100000, 'gamma': 0.005, 'kernel': 'rbf'}

# %%
# Membuat model SVM baru dengan parameter terbaik hasil grid search
model_baru = SVR (C= 10000, gamma = 0.005, kernel = "rbf")
model_baru.fit(X, y)
# Out:
# SVR(C=10000, gamma=0.005)

# %%
import matplotlib.pyplot as plt
plt.scatter(X, y)
plt.plot(X, model_baru.predict(X))

# %%
import pandas as pd

Developer = pd.DataFrame({'Name': ['Isyana Saraswati', 'Nicholas Saputra', 'Raisa Andriana'],
        'Age':[30, 36, 32]})
print("Machine Learning Developer di Indonesia :\n", Developer)

Developer[['First','Last']] = Developer.Name.str.split(expand=True)
print("\n Split kolom 'Name', lalu tambahkan kedua kolom : \n", Developer)
# Out:
# Machine Learning Developer di Indonesia :
#                 Name  Age
# 0  Isyana Saraswati   30
# 1  Nicholas Saputra   36
# 2    Raisa Andriana   32
#
#  Split kolom 'Name', lalu tambahkan kedua kolom :
#                 Name  Age     First       Last
# 0  Isyana Saraswati   30    Isyana  Saraswati
# 1  Nicholas Saputra   36  Nicholas    Saputra
# 2    Raisa Andriana   32     Raisa   Andriana

# %% [markdown]
# # **Latihan Membuat Model Klasifikasi Gamba**r
#
#
# 1. Memastikan TensorFlow yang digunakan di Google Colab adalah versi di atas 2.0.
#
# 2. Mengunduh dataset dan melakukan extract file dengan metode unzip.
#
# 3. Menampung direktori setiap kelas pada direktori train dan validasi ke dalam variabel.
#
# 4. Pre-processing data dengan image augmentation.
#
# 5. Mempersiapkan data latih yang akan dipelajari oleh model.
#
# 6. Membangun arsitektur model dengan Convolutional Neural Network (CNN).
#
# 7. Compile dan latih model dengan model.compile dan model.fit hingga mendapatkan akurasi yang diinginkan.
#
# 8. Menguji model yang telah dibuat dengan menggunakan gambar yang belum dikenali oleh model.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %%
# Mengunduh dataset

# !wget --no-check-certificate \
  https://dicoding-academy-assets.sgp1.cdn.digitaloceanspaces.com/184/messy-vs-clean-room.zip \
  -O /tmp/messy_vs_clean_room.zip
# Out:
# --2024-06-06 07:13:27--  https://dicoding-academy-assets.sgp1.cdn.digitaloceanspaces.com/184/messy-vs-clean-room.zip
# Resolving dicoding-academy-assets.sgp1.cdn.digitaloceanspaces.com (dicoding-academy-assets.sgp1.cdn.digitaloceanspaces.com)... 104.18.42.227, 172.64.145.29, 2606:4700:4400::6812:2ae3, ...
# Connecting to dicoding-academy-assets.sgp1.cdn.digitaloceanspaces.com (dicoding-academy-assets.sgp1.cdn.digitaloceanspaces.com)|104.18.42.227|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Cookie coming from dicoding-academy-assets.sgp1.cdn.digitaloceanspaces.com attempted to set domain to digitaloceanspaces.com
# Length: 70392746 (67M) [application/zip]
# Saving to: ‘/tmp/messy_vs_clean_room.zip’
#
# /tmp/messy_vs_clean 100%[===================>]  67.13M   179MB/s    in 0.4s
#
# 2024-06-06 07:13:28 (179 MB/s) - ‘/tmp/messy_vs_clean_room.zip’ saved [70392746/70392746]

# %%
# Melakukan ekstraksi pada file ZIP

import zipfile, os
local_zip = '/tmp/messy_vs_clean_room.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

base_dir = '/tmp/images'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'val')

# %%
os.listdir('/tmp/images/train')
# Out:
# ['clean', 'messy']

# %%
os.listdir('/tmp/images/val')
# Out:
# ['clean', 'messy']

# %%
# Mempersiapkan Train dan Test

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
                rescale = 1./255,
                rotation_range = 20,
                horizontal_flip = True,
                shear_range = 0.2,
                fill_mode = "nearest" )

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# Menyiapkan data Train dan validasi dari kumpulan data gambar
train_generator = train_datagen.flow_from_directory(
        train_dir,  # direktori data latih
        target_size=(150, 150),  # mengubah resolusi seluruh gambar menjadi 150x150 piksel
        batch_size=4,
        # karena ini merupakan masalah klasifikasi 2 kelas, gunakan class_mode = 'binary'
        class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
        validation_dir, # direktori data validasi
        target_size=(150, 150), # mengubah resolusi seluruh gambar menjadi 150x150 piksel
        batch_size=4, # karena ini merupakan masalah klasifikasi 2 kelas gunakan class_mode = 'binary'
        class_mode='binary')
# Out:
# Found 192 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(512, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 74, 74, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 36, 36, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 17, 17, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 512)       590336
#
#  max_pooling2d_3 (MaxPoolin  (None, 7, 7, 512)         0
#  g2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 512)               12845568
#
#  dense_1 (Dense)             (None, 1)                 513
#
# ...
# Total params: 13529665 (51.61 MB)
# Trainable params: 13529665 (51.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %%
# compile model dengan 'adam' optimizer loss function 'binary_crossentropy'
model.compile(loss='binary_crossentropy',
              optimizer=tf.optimizers.Adam(),
              metrics=['accuracy'])

# %%
# latih model dengan model.fit
model.fit(
      train_generator,
      steps_per_epoch=25,  # berapa batch yang akan dieksekusi pada setiap epoch
      epochs=20, # tambahkan epochs jika akurasi model belum optimal
      validation_data=validation_generator, # menampilkan akurasi pengujian data validasi
      validation_steps=5,  # berapa batch yang akan dieksekusi pada setiap epoch
      verbose=2)
# Out:
# Epoch 1/20
# 25/25 - 21s - loss: 0.7496 - accuracy: 0.5300 - val_loss: 0.7048 - val_accuracy: 0.5000 - 21s/epoch - 840ms/step
# Epoch 2/20
# 25/25 - 20s - loss: 0.6857 - accuracy: 0.5100 - val_loss: 0.6236 - val_accuracy: 0.5000 - 20s/epoch - 781ms/step
# Epoch 3/20
# 25/25 - 18s - loss: 0.7008 - accuracy: 0.4700 - val_loss: 0.6920 - val_accuracy: 0.5000 - 18s/epoch - 731ms/step
# Epoch 4/20
# 25/25 - 16s - loss: 0.7141 - accuracy: 0.6000 - val_loss: 0.6938 - val_accuracy: 0.5000 - 16s/epoch - 620ms/step
# Epoch 5/20
# 25/25 - 16s - loss: 0.6985 - accuracy: 0.5900 - val_loss: 0.6955 - val_accuracy: 0.5000 - 16s/epoch - 652ms/step
# Epoch 6/20
# 25/25 - 16s - loss: 0.6771 - accuracy: 0.5600 - val_loss: 0.7049 - val_accuracy: 0.5000 - 16s/epoch - 647ms/step
# Epoch 7/20
# 25/25 - 15s - loss: 0.6856 - accuracy: 0.6000 - val_loss: 0.6182 - val_accuracy: 0.6000 - 15s/epoch - 612ms/step
# Epoch 8/20
# ...

# %%
import numpy as np
from google.colab import files
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

uploaded = files.upload()

for fn in uploaded.keys():

  # predicting images
  path = fn
  img = image.load_img(path, target_size=(150,150))

  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
  images = np.vstack([x])

  classes = model.predict(images, batch_size=10)
  print(fn)
  if classes==0:
   print('clean')
  else:
   print('messy')
# Out:
#      <input type="file" id="files-ac89c942-084b-4ace-b71a-510b8820993a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac89c942-084b-4ace-b71a-510b8820993a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
